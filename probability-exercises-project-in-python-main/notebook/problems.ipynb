# %% [markdown]
# # Probability exercises

# %% [markdown]
# ### Exercise 1
#
# Two unbiased dice are thrown once and the total score is observed. Use a simulation to find the estimated probability that the total score is even or greater than 7
#
# We could use a mathematical equation to solve this or we can run the experiment many times, and then count the number of times where the score is even or greater than 7
#
# -Run the experiment 1000 times (roll 2 dice 1000 times, and sum the result)
#
# -Keep track of the number of times that the sum was either greater than 7 or an even number
#
# -Divide the number from step 2 by the number of iterations (1000)

# %%
#import libraries
import numpy as np
import random

#Funtion to roll the dice.
iteraciones = 1000
num_iteraciones = 0

for i in range(iteraciones):
    res = random.randint(1,6) + random.randint(1,6) # each random function rolls a random die
    if ((res %2==0) | (res>7)): # if the result of adding the dice is greater than 7 or a multiple of 2, add 1 to the variable
        num_iteraciones += 1

probabilidad = round((num_iteraciones/iteraciones)*100, 2)

print('Probabilidad de que la suma sea > 7 o sea par = {:.2f} %'.format(probabilidad))
# Out:
# Probabilidad de que la suma sea > 7 o sea par = 64.00 %

# %% [markdown]
# ### Exercise 2
#
# A box contains 10 white balls, 20 reds and 30 greens. Draw 5 balls with replacement. What is the probability that:
#
# a. 3 white or 2 red
#
# b. All 5 are the same color
#
#
# We will use the same system here. We will pick our balls during each round and count the number of times that:
#
# a. 3 white or 2 red
#
# b. All 5 are the same color.

# %%
bolas = {}

for i in range(60):
    
    if i < 10:
        bolas[i] = 'White'
    elif i > 9 and i < 30:
        bolas[i] = 'Red'
    else:
        bolas[i] = 'Green'  
print(bolas)  
       
#Initialize important variables

simulations = 1000
a = 0 
b = 0


for i in range(simulations):
    
   # Make a list
    lista = []
    
    for i in range(5):
        lista.append(bolas[random.randint(0,59)]) # choose random the 5 colors
        
    #Convert it to a numpy array
    lista = np.array(lista) 

    #find the number of each taht we picked
    white = sum(lista == 'White')
    red = sum(lista == 'Red')
    green = sum(lista == 'Green')

    #Keep track if the combination met the criteria
    if white == 3 and red == 2:
        a += 1
    
    if red == 5 or white == 5 or green ==5:
        b +=1

print('The probability of 3 white and 2 red is:', round((a/simulations)*100,5),'%') # Round an array to the given number of decimals
print('The probability of all the same color is:', round((b/simulations)*100,3),'%')
# Out:
# {0: 'White', 1: 'White', 2: 'White', 3: 'White', 4: 'White', 5: 'White', 6: 'White', 7: 'White', 8: 'White', 9: 'White', 10: 'Red', 11: 'Red', 12: 'Red', 13: 'Red', 14: 'Red', 15: 'Red', 16: 'Red', 17: 'Red', 18: 'Red', 19: 'Red', 20: 'Red', 21: 'Red', 22: 'Red', 23: 'Red', 24: 'Red', 25: 'Red', 26: 'Red', 27: 'Red', 28: 'Red', 29: 'Red', 30: 'Green', 31: 'Green', 32: 'Green', 33: 'Green', 34: 'Green', 35: 'Green', 36: 'Green', 37: 'Green', 38: 'Green', 39: 'Green', 40: 'Green', 41: 'Green', 42: 'Green', 43: 'Green', 44: 'Green', 45: 'Green', 46: 'Green', 47: 'Green', 48: 'Green', 49: 'Green', 50: 'Green', 51: 'Green', 52: 'Green', 53: 'Green', 54: 'Green', 55: 'Green', 56: 'Green', 57: 'Green', 58: 'Green', 59: 'Green'}
# The probability of 3 white and 2 red is: 0.8 %
# The probability of all the same color is: 4.4 %

# %%
bolas = {}

for i in range(60):
    
    if i < 10:
        bolas[i] = 'White'
    elif i > 9 and i < 30:
        bolas[i] = 'Red'
    else:
        bolas[i] = 'Green'  
     
#Initialize important variables

simulations = 1000
a = 0
b = 0
c = 0

for i in range(simulations):
    
   # Make a list
    lista = []
    
    for i in range(5):
        lista.append(bolas[np.random.randint(0,60)]) # choose random the 5 colors
        
    #Convert it to a numpy array
    lista = np.array(lista)
   
    valor, contador = np.unique(lista, return_counts=True)
    
    
    if ('White' in valor) and ('Red' in valor):
        if (contador[np.where(valor == 'White')] == 3) or (contador[np.where(valor == 'Red')] == 2):
            a += 1
    
    if ('White' in valor) and ('Red' in valor) and ('Green' in valor):
        if (contador[np.where(valor== 'White')] == 5) or (contador[np.where(valor== 'Red')] == 2) or (contador[np.where(valor== 'Green')] == 5):
            c += 1

 
print('The probability of 3 white and 2 red is:', round((a/simulations)*100,5),'%') # Round an array to the given number of decimals

print('The probability of all the same color is:', round((c/simulations)*100,5),'%')
# Out:
# The probability of 3 white and 2 red is: 20.4 %
# The probability of all the same color is: 19.1 %
